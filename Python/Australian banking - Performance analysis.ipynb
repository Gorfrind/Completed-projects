# %%
from math import *
import numpy as np
import pandas as pd
from pathlib import Path
from IPython.display import display, HTML
import seaborn as sns
sns.set_style('white')

# colormap definitions
from matplotlib import cm 

# %matplotlib inline
import matplotlib.pyplot as plt

import string
import openpyxl
import xlrd
import csv

# %% [markdown]
# Data from https://www.rba.gov.au/statistics/tables/

# %%
path = Path("../downloads/a1-data-detailed.csv")
df = pd.read_csv(path, header=[1])
df.dropna(thresh=2, inplace=True)
df.drop(df.columns[[-1,-2]],axis=1, inplace=True)
df.drop(df.index[[i for i in range(7)]], inplace=True)
df.rename(columns={'Title': 'Date'}, inplace=True)
cols = df.columns.drop('Date')
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')
df['Date'] = pd.to_datetime(df['Date'])
df = df.reset_index(drop=True)
print(df.dtypes)
df.head(25)
# Out:
# Date                                     datetime64[ns]
# Capital and Reserve Bank Reserve Fund             int64
# Notes on issue                                    int64
# Exchange settlement balances                      int64
# RBA term deposits                               float64
# Deposits of overseas institutions                 int64
# Australian Government Deposits                    int64
# State Governments Deposits                        int64
# Other Deposits                                    int64
# Other liabilities                                 int64
# Total liabilities                                 int64
# Gold and foreign exchange                         int64
# Australian dollar investments                     int64
# Loans and advances                                int64
# Clearing items                                    int64
# Other assets                                      int64
# Total assets                                      int64
# dtype: object
#          Date  Capital and Reserve Bank Reserve Fund  Notes on issue  \
# 0  1994-06-01                                    633           17231
# 1  1994-06-08                                    633           17301
# 2  1994-06-15                                    633           17477
# 3  1994-06-22                                    633           17402
# 4  1994-06-29                                    633           17450
# 5  1994-07-06                                    633           17495
# 6  1994-07-13                                    633           17515
# 7  1994-07-20                                    633           17533
# 8  1994-07-27                                    633           17562
# 9  1994-08-03                                    633           17587
# 10 1994-08-10                                    633           17573
# 11 1994-08-17                                    633           17607
# 12 1994-08-24                                    633           17626
# 13 1994-08-31                                    633           17628
# 14 1994-09-07                                    633           17611
# 15 1994-09-14                                    633           17636
# 16 1994-09-21                                    633           17716
# 17 1994-09-28                                    633           17795
# 18 1994-10-05                                    633           17895
# 19 1994-10-12                                    633           17814
# 20 1994-10-19                                    633           17843
# 21 1994-10-26                                    633           17865
# 22 1994-11-02                                    633           17979
# 23 1994-11-09                                    633           17980
# 24 1994-11-16                                    633           18010
#
#     Exchange settlement balances  RBA term deposits  \
# 0                           3241                NaN
# 1                           3238                NaN
# 2                           3275                NaN
# 3                           3355                NaN
# 4                           3275                NaN
# 5                           3764                NaN
# 6                           3763                NaN
# 7                           3807                NaN
# 8                           3805                NaN
# 9                           3306                NaN
# 10                          3306                NaN
# 11                          3360                NaN
# 12                          3348                NaN
# 13                          3345                NaN
# 14                          3344                NaN
# 15                          3349                NaN
# 16                          3360                NaN
# 17                          3359                NaN
# 18                          3360                NaN
# 19                          3363                NaN
# 20                          3391                NaN
# 21                          3389                NaN
# 22                          3391                NaN
# 23                          3587                NaN
# 24                          3404                NaN
#
#     Deposits of overseas institutions  Australian Government Deposits  \
# 0                                 459                            2059
# 1                                 463                            2291
# 2                                 462                            1815
# 3                                 458                            2099
# 4                                 468                            1674
# 5                                 465                            1561
# 6                                 445                            3167
# 7                                 439                             565
# 8                                 435                            1791
# 9                                 476                            3417
# 10                                439                            4332
# 11                                448                            2082
# 12                                447                            2046
# 13                                443                            1541
# 14                                465                            2605
# 15                                466                            2413
# 16                                466                            1194
# 17                                485                            1241
# 18                                484                            1203
# 19                                467                            2014
# 20                                459                            1787
# 21                                458                            1716
# 22                                454                             782
# 23                                459                             626
# 24                                451                            1054
#
#     State Governments Deposits  Other Deposits  Other liabilities  \
# 0                           50              37               9755
# 1                           24              30               9208
# 2                           84              61               9493
# 3                           28              34               9542
# 4                           32              29              10842
# 5                           31              62               9524
# 6                           46              46               9391
# 7                           69              49               9904
# 8                           30              32               9729
# 9                           33              62               9673
# 10                          51              40               9125
# 11                          38              35               9298
# 12                          24              34              10041
# 13                          21              36               8561
# 14                          48              40               8142
# 15                          27              37               8054
# 16                          17              36               8821
# 17                          20              42               8669
# 18                          45              44               8397
# 19                          85              42               8360
# 20                           9              40               8420
# 21                          27              40               9024
# 22                          34              42               8793
# 23                          17              43               7968
# 24                          45              51               7993
#
#     Total liabilities  Gold and foreign exchange  \
# 0               33465                      19179
# 1               33188                      19183
# 2               33300                      19477
# 3               33551                      19545
# 4               34403                      20227
# 5               33535                      20083
# 6               35006                      19966
# 7               32999                      19843
# 8               34017                      19788
# 9               35187                      19804
# 10              35499                      19591
# 11              33501                      19617
# 12              34199                      19954
# 13              32208                      19738
# 14              32888                      19940
# 15              32615                      19914
# 16              32243                      20084
# 17              32244                      19645
# 18              32061                      19549
# 19              32778                      19524
# 20              32582                      19858
# 21              33152                      19959
# 22              32108                      18843
# 23              31313                      18567
# 24              31641                      18359
#
#     Australian dollar investments  Loans and advances  Clearing items  \
# 0                           13680                 102               0
# 1                           13055                  98             354
# 2                           13086                  98             159
# 3                           12802                  99             610
# 4                           13563                  98              14
# 5                           12179                  93             671
# 6                           14325                  92             114
# 7                           12563                  92               1
# 8                           13638                  92               1
# 9                           14801                  93               0
# 10                          15038                  92             282
# 11                          12508                  92             774
# 12                          13682                  91               0
# 13                          11886                  92               0
# 14                          12376                  91               0
# 15                          12133                  91               0
# 16                          11589                  91               0
# 17                          12029                  90               2
# 18                          11929                  91               1
# 19                          12661                  91               0
# 20                          12131                  90               1
# 21                          12597                  90               0
# 22                          12677                  91               0
# 23                          12145                  91               0
# 24                          12677                  90               1
#
#     Other assets  Total assets
# 0            504         33465
# 1            498         33188
# 2            480         33300
# 3            495         33551
# 4            501         34403
# 5            509         33535
# 6            509         35006
# 7            500         32999
# 8            498         34017
# 9            489         35187
# 10           496         35499
# 11           510         33501
# 12           472         34199
# 13           492         32208
# 14           481         32888
# 15           477         32615
# 16           479         32243
# 17           478         32244
# 18           491         32061
# 19           502         32778
# 20           502         32582
# 21           506         33152
# 22           497         32108
# 23           510         31313
# 24           514         31641

# %%
ax= df.set_index('Date', inplace=False).plot(linewidth=5,figsize=(30,30))
ax.legend( prop={'size': 20})
ax.tick_params(axis='both', which='major', labelsize=20)
ax.tick_params(axis='both', which='minor', labelsize=20)
plt.show()

# %%
df.plot(x='Date', y='Total assets')

# %% [markdown]
# ## Visualisation of the Global Financial Crisis (GFC)

# %%
df[(df['Date'] > '2007-01-01') & (df['Date'] < '2009-01-01')].plot(x='Date', y='Total assets')
plt.show()

# %%
df[(df['Date'] > '2007-01-01') & (df['Date'] < '2009-01-01')].plot(subplots=True, layout=(6,3), figsize=(15,25))
plt.show()

# %% [markdown]
# ## Visualisation of the Asian Financial Crisis

# %%
df[(df['Date'] > '1997-01-01') & (df['Date'] < '2000-01-01')].plot(x='Date', y='Total assets')
plt.show()

# %%
df[(df['Date'] > '1997-01-01') & (df['Date'] < '2000-01-01')].plot(subplots=True, layout=(6,3), figsize=(15,25))
plt.show()

# %%
df['% Total Assets change']= df['Total assets'].pct_change()*100

# %%
a=df.groupby(df.Date.dt.year)['% Total Assets change']
print(a.sum(),'\n\n',a.mean())
a.sum().plot(title="Average every year (percentage) change in Total Assets ")
plt.show()

a.mean().plot(title="Average daily (percentage) change in Total Assets for each year")
plt.show()
# Out:
# Date
# 1994    -3.307102
# 1995    20.989374
# 1996    19.363270
# 1997    -0.817087
# 1998    16.703114
# 1999     9.391469
# 2000    11.636473
# 2001    15.324064
# 2002     4.206282
# 2003    11.704073
# 2004    12.526468
# 2005    30.329090
# 2006    34.408479
# 2007   -17.253328
# 2008    63.153836
# 2009   -57.386742
# 2010    -7.703621
# 2011    21.861278
# 2012    20.219238
# 2013    39.946187
# 2014    19.598489
# 2015     6.095303
# 2016    13.867434
# 2017     8.757958
# 2018     0.713192
# 2019    -7.446373
# Name: % Total Assets change, dtype: float64
#
#  Date
# 1994   -0.110237
# 1995    0.403642
# 1996    0.372371
# 1997   -0.015417
# 1998    0.321214
# 1999    0.180605
# 2000    0.223778
# 2001    0.294694
# 2002    0.080890
# 2003    0.220832
# 2004    0.240894
# 2005    0.583252
# 2006    0.661702
# 2007   -0.331795
# 2008    1.191582
# 2009   -1.103591
# 2010   -0.148147
# 2011    0.420409
# 2012    0.388832
# 2013    0.768196
# 2014    0.369783
# 2015    0.117217
# 2016    0.266681
# 2017    0.168422
# 2018    0.013715
# 2019   -0.438022
# Name: % Total Assets change, dtype: float64

# %%
list(df)
# Out:
# ['Date',
#  'Capital and Reserve Bank Reserve Fund',
#  'Notes on issue',
#  'Exchange settlement balances',
#  'RBA term deposits',
#  'Deposits of overseas institutions',
#  'Australian Government Deposits',
#  'State Governments Deposits',
#  'Other Deposits',
#  'Other liabilities',
#  'Total liabilities',
#  'Gold and foreign exchange',
#  'Australian dollar investments',
#  'Loans and advances',
#  'Clearing items',
#  'Other assets',
#  'Total assets',
#  '% Total Assets change']

# %%
x = list(df)
for i,j in enumerate(x):
    print(i,j)
# Out:
# 0 Date
# 1 Capital and Reserve Bank Reserve Fund
# 2 Notes on issue
# 3 Exchange settlement balances
# 4 RBA term deposits
# 5 Deposits of overseas institutions
# 6 Australian Government Deposits
# 7 State Governments Deposits
# 8 Other Deposits
# 9 Other liabilities
# 10 Total liabilities
# 11 Gold and foreign exchange
# 12 Australian dollar investments
# 13 Loans and advances
# 14 Clearing items
# 15 Other assets
# 16 Total assets
# 17 % Total Assets change

# %% [markdown]
# Below you can choose a year and column (use name from the above list) to view specific graphs)

# %%
x = input("Choose a year ")
y = input("Choose a column ")



df[(df['Date'].dt.year == int(x))][y].plot(subplots=True, layout=(6,3), figsize=(15,25))
plt.show()
# Out:
# Choose a year 2003
# Choose a column Total assets
